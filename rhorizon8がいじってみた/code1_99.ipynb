# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
import pandas
import math
# Out:
# 2023-12-06 02:34:47.303223: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-06 02:34:47.340535: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_file = "../train.tsv"
test_file = "../test.tsv"

train_data = pandas.read_csv(train_file, delimiter='\t').to_numpy()
train_data2 = np.empty((train_data.shape[0], train_data.shape[1]-2))
train_data2[:, 0:] = train_data[:, 2:]
train_data2[:,0:1] = train_data2[:, 0:1] * 2.7 / 4   #季節を正規化
train_data2[:,2:3] = train_data2[:, 2:3] * 1.8 / 12 #月を正規化
train_data2[:,3:4] = train_data2[:, 3:4] * 62.3 / 23 #時間を正規化
train_data2[:,5:6] = train_data2[:, 5:6] * 1.4 / 6.0   #曜日を正規化
train_data2[:,7:8] = train_data2[:, 7:8] * 2.2 / 4.0   #天気を正規化
train_data2[:,4:5] = train_data2[:, 4:5] * 0.2
train_data2[:,6:7] = train_data2[:, 6:7] * 5.6
train_data2[:,8:9] = train_data2[:, 8:9] * 9.5
train_data2[:,9:10] = train_data2[:, 9:10] * 8.9
train_data2[:,10:11] = train_data2[:, 10:11] * 3.4
train_data2[:,11:12] = train_data2[:, 11:12] * 1.5

train_data2 = train_data2#.astype(np.float32)
rnd = np.random.default_rng()
rnd.shuffle(train_data2,axis=0)

test_data = pandas.read_csv(test_file, delimiter='\t').to_numpy()
test_data2 = np.empty((test_data.shape[0], test_data.shape[1]-2))
test_data2[:, 0:] = test_data[:, 2:]
test_data2[:,0:1] = test_data2[:, 0:1] * 2.7 / 4   #季節を正規化
test_data2[:,2:3] = test_data2[:, 2:3] * 1.8 / 12 #月を正規化
test_data2[:,3:4] = test_data2[:, 3:4] * 62.3 / 23 #時間を正規化
test_data2[:,5:6] = test_data2[:, 5:6] * 1.4 / 6.0   #曜日を正規化
test_data2[:,7:8] = test_data2[:, 7:8] * 2.2 / 4.0   #天気を正規化
test_data2[:,4:5] = test_data2[:, 4:5] * 0.2
test_data2[:,6:7] = test_data2[:, 6:7] * 5.6
test_data2[:,8:9] = test_data2[:, 8:9] * 9.5
test_data2[:,9:10] = test_data2[:, 9:10] * 8.9
test_data2[:,10:11] = test_data2[:, 10:11] * 3.4
test_data2[:,11:12] = test_data2[:, 11:12] * 1.5
test_data2 = test_data2#.astype(np.float32)

#display(train_data2)
#display(test_data2)

x = train_data2[:, 12:]
x = x.reshape(x.shape[0], 1)
#print(x)
y = train_data2[:, :12]
y = y.reshape(y.shape[0], y.shape[1], 1)
#print(y)
test_y = test_data2.reshape(test_data2.shape[0], test_data2.shape[1], 1)
z = test_data2[:, :12]
z = z.reshape(z.shape[0], z.shape[1], 1)

# %%
osaka_file = "../test_local_osaka3.tsv"
osaka_data = pandas.read_csv(osaka_file, delimiter='\t').to_numpy()
osaka_data2 = np.empty((osaka_data.shape[0], osaka_data.shape[1]-2))
osaka_data2[:, 0:] = osaka_data[:, 2:]
osaka_data2[:,0:1] = osaka_data2[:, 0:1] * 2.7 / 4   #季節を正規化
osaka_data2[:,2:3] = osaka_data2[:, 2:3] * 1.8 / 12 #月を正規化
osaka_data2[:,3:4] = osaka_data2[:, 3:4] * 62.3 / 23 #時間を正規化
osaka_data2[:,5:6] = osaka_data2[:, 5:6] * 1.4 / 6.0   #曜日を正規化
osaka_data2[:,7:8] = osaka_data2[:, 7:8] * 2.2 / 4.0   #天気を正規化
osaka_data2[:,4:5] = osaka_data2[:, 4:5] * 0.2
osaka_data2[:,6:7] = osaka_data2[:, 6:7] * 5.6
osaka_data2[:,8:9] = osaka_data2[:, 8:9] * 9.5
osaka_data2[:,9:10] = osaka_data2[:, 9:10] * 8.9
osaka_data2[:,10:11] = osaka_data2[:, 10:11] * 3.4
osaka_data2[:,11:12] = osaka_data2[:, 11:12] * 1.5
osaka_data2 = osaka_data2.astype(np.float32)
osaka_y = osaka_data2.reshape(osaka_data2.shape[0], osaka_data2.shape[1], 1)
#display(osaka_data2)

# %%
length_of_sequence = y.shape[1]
#print(length_of_sequence)
in_out_neurons = 1 #入出力ノード数
n_hidden = 1024  #隠れ層 -> 数が多い程，学習モデルの複雑さが増加 #増やした

model = Sequential()
model.add(LSTM(n_hidden, input_shape=(length_of_sequence, in_out_neurons), return_sequences=False))
model.add(Dense(in_out_neurons))
model.add(Activation("linear"))
optimizer = Adam(learning_rate=0.001)
model.compile(loss="mean_squared_error", optimizer=optimizer, metrics=["accuracy"])
# Out:
# 2023-12-06 02:34:50.506342: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-06 02:34:50.529128: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-06 02:34:50.529165: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-06 02:34:50.532367: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-06 02:34:50.532399: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-06 02:34:50.532408: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-06 02:34:51.137460: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-06 02:34:51.137507: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-06 02:34:51.137512: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1726] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-12-06 02:34:51.137526: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-06 02:34:51.137548: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5348 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
#def build_model(hp):
#  import keras
#  model = keras.Sequential()
#  model.add(keras.layers.Dense(
#      hp.Choice('units', [8, 16, 32]),
#      activation='relu'))
#  model.add(keras.layers.Dense(1, activation='relu'))
#  model.compile(loss='mse')
#  return model

#tuner = kt.RandomSearch(
#    build_model,
#    objective='val_loss',
#    max_trials=5)

#tuner.search(train_data2, epochs=5, validation_data=(train_data2))
#best_model = tuner.get_best_models()[0]

# %%
ES = EarlyStopping(mode='auto', patience=128)
model.fit(y, x,
          batch_size=16, #デフォは32
          epochs=512, #512epochで学習
          validation_split=0.01, #学習データの5%をvalidationに用いる
          callbacks=[ES]
          )
# Out:
# Epoch 1/512
# 2023-12-06 02:34:54.442281: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8905
# 2023-12-06 02:34:55.198199: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-06 02:34:55.228013: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f968c14ef00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-06 02:34:55.228050: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# 2023-12-06 02:34:55.234125: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-06 02:34:55.320744: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 535/535 [==============================] - 6s 6ms/step - loss: 17477.8105 - accuracy: 0.0123 - val_loss: 11051.7021 - val_accuracy: 0.0115
# Epoch 2/512
# 535/535 [==============================] - 3s 5ms/step - loss: 11553.5264 - accuracy: 0.0125 - val_loss: 7772.9116 - val_accuracy: 0.0115
# Epoch 3/512
# 535/535 [==============================] - 3s 5ms/step - loss: 10439.1787 - accuracy: 0.0126 - val_loss: 7815.2090 - val_accuracy: 0.0115
# Epoch 4/512
# 535/535 [==============================] - 3s 5ms/step - loss: 9749.1699 - accuracy: 0.0126 - val_loss: 6129.3311 - val_accuracy: 0.0115
# Epoch 5/512
# 535/535 [==============================] - 3s 5ms/step - loss: 8928.1807 - accuracy: 0.0124 - val_loss: 5086.9937 - val_accuracy: 0.0115
# Epoch 6/512
# 535/535 [==============================] - 3s 5ms/step - loss: 7545.9805 - accuracy: 0.0126 - val_loss: 3998.2471 - val_accuracy: 0.0115
# Epoch 7/512
# 535/535 [==============================] - 3s 5ms/step - loss: 5354.3589 - accuracy: 0.0126 - val_loss: 2797.5447 - val_accuracy: 0.0115
# Epoch 8/512
# 535/535 [==============================] - 3s 5ms/step - loss: 4584.8774 - accuracy: 0.0123 - val_loss: 1913.5192 - val_accuracy: 0.0115
# Epoch 9/512
# 535/535 [==============================] - 3s 5ms/step - loss: 3930.6843 - accuracy: 0.0124 - val_loss: 2092.8076 - val_accuracy: 0.0115
# Epoch 10/512
# 535/535 [==============================] - 3s 5ms/step - loss: 3423.1941 - accuracy: 0.0124 - val_loss: 1898.3229 - val_accuracy: 0.0115
# Epoch 11/512
# 535/535 [==============================] - 3s 5ms/step - loss: 3357.8911 - accuracy: 0.0122 - val_loss: 1664.3547 - val_accuracy: 0.0115
# Epoch 12/512
# 535/535 [==============================] - 3s 5ms/step - loss: 3339.7310 - accuracy: 0.0126 - val_loss: 1731.2225 - val_accuracy: 0.0115
# Epoch 13/512
# 535/535 [==============================] - 3s 5ms/step - loss: 3919.2219 - accuracy: 0.0125 - val_loss: 2726.2964 - val_accuracy: 0.0115
# Epoch 14/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2888.0222 - accuracy: 0.0126 - val_loss: 1298.0042 - val_accuracy: 0.0115
# Epoch 15/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2613.3948 - accuracy: 0.0125 - val_loss: 1410.2296 - val_accuracy: 0.0000e+00
# Epoch 16/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2614.6440 - accuracy: 0.0123 - val_loss: 1118.5580 - val_accuracy: 0.0115
# Epoch 17/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2289.2119 - accuracy: 0.0119 - val_loss: 2009.8730 - val_accuracy: 0.0000e+00
# Epoch 18/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2621.5635 - accuracy: 0.0115 - val_loss: 1762.0654 - val_accuracy: 0.0115
# Epoch 19/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2280.8118 - accuracy: 0.0123 - val_loss: 1301.5552 - val_accuracy: 0.0000e+00
# Epoch 20/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2338.5352 - accuracy: 0.0119 - val_loss: 1731.5270 - val_accuracy: 0.0000e+00
# Epoch 21/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2182.3276 - accuracy: 0.0113 - val_loss: 1303.6078 - val_accuracy: 0.0115
# Epoch 22/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2203.2698 - accuracy: 0.0123 - val_loss: 1221.6344 - val_accuracy: 0.0000e+00
# Epoch 23/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2389.2869 - accuracy: 0.0111 - val_loss: 1294.1982 - val_accuracy: 0.0000e+00
# Epoch 24/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2021.0038 - accuracy: 0.0110 - val_loss: 1295.8252 - val_accuracy: 0.0115
# Epoch 25/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1877.0020 - accuracy: 0.0108 - val_loss: 1255.5544 - val_accuracy: 0.0115
# Epoch 26/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2128.6255 - accuracy: 0.0109 - val_loss: 1223.1731 - val_accuracy: 0.0115
# Epoch 27/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1968.5476 - accuracy: 0.0109 - val_loss: 1010.4390 - val_accuracy: 0.0000e+00
# Epoch 28/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1866.2390 - accuracy: 0.0122 - val_loss: 962.4410 - val_accuracy: 0.0115
# Epoch 29/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1655.3746 - accuracy: 0.0115 - val_loss: 1274.6327 - val_accuracy: 0.0000e+00
# Epoch 30/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2658.0022 - accuracy: 0.0110 - val_loss: 2111.6191 - val_accuracy: 0.0000e+00
# Epoch 31/512
# 535/535 [==============================] - 3s 5ms/step - loss: 2517.2563 - accuracy: 0.0111 - val_loss: 1479.2610 - val_accuracy: 0.0115
# Epoch 32/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1830.9154 - accuracy: 0.0116 - val_loss: 972.8906 - val_accuracy: 0.0115
# Epoch 33/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1737.2677 - accuracy: 0.0106 - val_loss: 1403.0729 - val_accuracy: 0.0115
# Epoch 34/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1616.5461 - accuracy: 0.0104 - val_loss: 1029.0834 - val_accuracy: 0.0000e+00
# Epoch 35/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1913.8036 - accuracy: 0.0104 - val_loss: 1036.5358 - val_accuracy: 0.0000e+00
# Epoch 36/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1664.3207 - accuracy: 0.0112 - val_loss: 955.3081 - val_accuracy: 0.0115
# Epoch 37/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1423.8644 - accuracy: 0.0106 - val_loss: 996.9865 - val_accuracy: 0.0000e+00
# Epoch 38/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1502.4021 - accuracy: 0.0110 - val_loss: 1025.1515 - val_accuracy: 0.0115
# Epoch 39/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1487.1808 - accuracy: 0.0111 - val_loss: 986.1256 - val_accuracy: 0.0115
# Epoch 40/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1485.3695 - accuracy: 0.0110 - val_loss: 956.4327 - val_accuracy: 0.0115
# Epoch 41/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1320.7806 - accuracy: 0.0110 - val_loss: 983.7863 - val_accuracy: 0.0000e+00
# Epoch 42/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1561.2430 - accuracy: 0.0110 - val_loss: 961.3148 - val_accuracy: 0.0115
# Epoch 43/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1246.7635 - accuracy: 0.0111 - val_loss: 1072.1514 - val_accuracy: 0.0000e+00
# Epoch 44/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1601.6082 - accuracy: 0.0104 - val_loss: 1031.3027 - val_accuracy: 0.0000e+00
# Epoch 45/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1218.6334 - accuracy: 0.0106 - val_loss: 978.3796 - val_accuracy: 0.0115
# Epoch 46/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1195.6169 - accuracy: 0.0111 - val_loss: 875.7902 - val_accuracy: 0.0115
# Epoch 47/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1342.5778 - accuracy: 0.0109 - val_loss: 864.0669 - val_accuracy: 0.0115
# Epoch 48/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1144.3815 - accuracy: 0.0116 - val_loss: 1021.8472 - val_accuracy: 0.0115
# Epoch 49/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1266.7770 - accuracy: 0.0115 - val_loss: 946.2498 - val_accuracy: 0.0000e+00
# Epoch 50/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1330.8246 - accuracy: 0.0113 - val_loss: 1194.3883 - val_accuracy: 0.0115
# Epoch 51/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1908.6167 - accuracy: 0.0111 - val_loss: 1072.2411 - val_accuracy: 0.0115
# Epoch 52/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1613.9987 - accuracy: 0.0111 - val_loss: 1057.9370 - val_accuracy: 0.0115
# Epoch 53/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1327.9310 - accuracy: 0.0115 - val_loss: 1029.2496 - val_accuracy: 0.0000e+00
# Epoch 54/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1297.8667 - accuracy: 0.0109 - val_loss: 941.3188 - val_accuracy: 0.0115
# Epoch 55/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1210.2183 - accuracy: 0.0116 - val_loss: 921.8824 - val_accuracy: 0.0115
# Epoch 56/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1097.6205 - accuracy: 0.0109 - val_loss: 942.1053 - val_accuracy: 0.0115
# Epoch 57/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1055.4430 - accuracy: 0.0116 - val_loss: 928.9851 - val_accuracy: 0.0115
# Epoch 58/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1117.4850 - accuracy: 0.0117 - val_loss: 870.5162 - val_accuracy: 0.0000e+00
# Epoch 59/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1043.7649 - accuracy: 0.0116 - val_loss: 967.9905 - val_accuracy: 0.0115
# Epoch 60/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1213.6241 - accuracy: 0.0105 - val_loss: 1020.4149 - val_accuracy: 0.0115
# Epoch 61/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1078.5956 - accuracy: 0.0111 - val_loss: 1103.4496 - val_accuracy: 0.0000e+00
# Epoch 62/512
# 535/535 [==============================] - 3s 5ms/step - loss: 962.5609 - accuracy: 0.0112 - val_loss: 806.5328 - val_accuracy: 0.0115
# Epoch 63/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1208.1310 - accuracy: 0.0119 - val_loss: 965.6357 - val_accuracy: 0.0000e+00
# Epoch 64/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1037.0454 - accuracy: 0.0115 - val_loss: 851.2359 - val_accuracy: 0.0115
# Epoch 65/512
# 535/535 [==============================] - 3s 5ms/step - loss: 974.7173 - accuracy: 0.0113 - val_loss: 940.0229 - val_accuracy: 0.0115
# Epoch 66/512
# 535/535 [==============================] - 3s 5ms/step - loss: 977.9779 - accuracy: 0.0118 - val_loss: 824.8939 - val_accuracy: 0.0115
# Epoch 67/512
# 535/535 [==============================] - 3s 5ms/step - loss: 886.7606 - accuracy: 0.0120 - val_loss: 873.5528 - val_accuracy: 0.0115
# Epoch 68/512
# 535/535 [==============================] - 3s 5ms/step - loss: 844.1211 - accuracy: 0.0113 - val_loss: 774.2661 - val_accuracy: 0.0000e+00
# Epoch 69/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1031.6682 - accuracy: 0.0111 - val_loss: 986.7401 - val_accuracy: 0.0115
# Epoch 70/512
# 535/535 [==============================] - 3s 5ms/step - loss: 886.6806 - accuracy: 0.0117 - val_loss: 620.5018 - val_accuracy: 0.0115
# Epoch 71/512
# 535/535 [==============================] - 3s 5ms/step - loss: 801.4350 - accuracy: 0.0118 - val_loss: 839.7610 - val_accuracy: 0.0115
# Epoch 72/512
# 535/535 [==============================] - 3s 5ms/step - loss: 786.0116 - accuracy: 0.0112 - val_loss: 782.1196 - val_accuracy: 0.0115
# Epoch 73/512
# 535/535 [==============================] - 3s 5ms/step - loss: 762.3045 - accuracy: 0.0122 - val_loss: 860.5806 - val_accuracy: 0.0115
# Epoch 74/512
# 535/535 [==============================] - 3s 5ms/step - loss: 1064.3154 - accuracy: 0.0117 - val_loss: 962.6363 - val_accuracy: 0.0115
# Epoch 75/512
# 535/535 [==============================] - 3s 5ms/step - loss: 727.9180 - accuracy: 0.0122 - val_loss: 846.1617 - val_accuracy: 0.0115
# Epoch 76/512
# 535/535 [==============================] - 3s 5ms/step - loss: 699.1686 - accuracy: 0.0113 - val_loss: 854.2513 - val_accuracy: 0.0115
# Epoch 77/512
# 535/535 [==============================] - 3s 5ms/step - loss: 924.8579 - accuracy: 0.0117 - val_loss: 2686.1646 - val_accuracy: 0.0115
# Epoch 78/512
# 535/535 [==============================] - 3s 5ms/step - loss: 832.1049 - accuracy: 0.0118 - val_loss: 878.5067 - val_accuracy: 0.0115
# Epoch 79/512
# 535/535 [==============================] - 3s 5ms/step - loss: 651.1635 - accuracy: 0.0122 - val_loss: 959.3654 - val_accuracy: 0.0115
# Epoch 80/512
# 535/535 [==============================] - 3s 5ms/step - loss: 867.1144 - accuracy: 0.0116 - val_loss: 821.3990 - val_accuracy: 0.0000e+00
# Epoch 81/512
# 535/535 [==============================] - 3s 5ms/step - loss: 680.3309 - accuracy: 0.0110 - val_loss: 774.2097 - val_accuracy: 0.0115
# Epoch 82/512
# 535/535 [==============================] - 3s 5ms/step - loss: 790.6198 - accuracy: 0.0115 - val_loss: 1078.6143 - val_accuracy: 0.0115
# Epoch 83/512
# 535/535 [==============================] - 3s 5ms/step - loss: 740.6890 - accuracy: 0.0109 - val_loss: 858.2004 - val_accuracy: 0.0115
# Epoch 84/512
# 535/535 [==============================] - 3s 5ms/step - loss: 609.1776 - accuracy: 0.0117 - val_loss: 937.5460 - val_accuracy: 0.0115
# Epoch 85/512
# 535/535 [==============================] - 3s 5ms/step - loss: 633.2643 - accuracy: 0.0123 - val_loss: 912.0703 - val_accuracy: 0.0115
# Epoch 86/512
# 535/535 [==============================] - 3s 5ms/step - loss: 716.7568 - accuracy: 0.0120 - val_loss: 701.9358 - val_accuracy: 0.0115
# Epoch 87/512
# 535/535 [==============================] - 3s 5ms/step - loss: 615.9832 - accuracy: 0.0116 - val_loss: 840.1837 - val_accuracy: 0.0115
# Epoch 88/512
# 535/535 [==============================] - 3s 5ms/step - loss: 709.7608 - accuracy: 0.0119 - val_loss: 697.0694 - val_accuracy: 0.0115
# Epoch 89/512
# 535/535 [==============================] - 3s 5ms/step - loss: 538.3256 - accuracy: 0.0119 - val_loss: 745.4695 - val_accuracy: 0.0115
# Epoch 90/512
# 535/535 [==============================] - 3s 5ms/step - loss: 652.2809 - accuracy: 0.0115 - val_loss: 778.7769 - val_accuracy: 0.0115
# Epoch 91/512
# 535/535 [==============================] - 3s 5ms/step - loss: 619.8741 - accuracy: 0.0119 - val_loss: 860.3182 - val_accuracy: 0.0115
# Epoch 92/512
# 535/535 [==============================] - 3s 5ms/step - loss: 770.6376 - accuracy: 0.0119 - val_loss: 882.2407 - val_accuracy: 0.0115
# Epoch 93/512
# 535/535 [==============================] - 3s 5ms/step - loss: 540.4643 - accuracy: 0.0109 - val_loss: 925.7384 - val_accuracy: 0.0115
# Epoch 94/512
# 535/535 [==============================] - 3s 5ms/step - loss: 928.9991 - accuracy: 0.0116 - val_loss: 794.3372 - val_accuracy: 0.0115
# Epoch 95/512
# 535/535 [==============================] - 3s 5ms/step - loss: 547.1859 - accuracy: 0.0117 - val_loss: 982.0081 - val_accuracy: 0.0115
# Epoch 96/512
# 535/535 [==============================] - 3s 5ms/step - loss: 718.3771 - accuracy: 0.0111 - val_loss: 1075.5254 - val_accuracy: 0.0115
# Epoch 97/512
# 535/535 [==============================] - 3s 5ms/step - loss: 539.7950 - accuracy: 0.0120 - val_loss: 855.6164 - val_accuracy: 0.0115
# Epoch 98/512
# 535/535 [==============================] - 3s 5ms/step - loss: 628.7821 - accuracy: 0.0118 - val_loss: 1053.7977 - val_accuracy: 0.0115
# Epoch 99/512
# 535/535 [==============================] - 3s 5ms/step - loss: 509.7096 - accuracy: 0.0115 - val_loss: 819.1415 - val_accuracy: 0.0115
# Epoch 100/512
# 535/535 [==============================] - 3s 5ms/step - loss: 459.8132 - accuracy: 0.0119 - val_loss: 826.7235 - val_accuracy: 0.0115
# Epoch 101/512
# 535/535 [==============================] - 3s 5ms/step - loss: 772.0175 - accuracy: 0.0119 - val_loss: 1061.3569 - val_accuracy: 0.0115
# Epoch 102/512
# 535/535 [==============================] - 3s 5ms/step - loss: 553.7272 - accuracy: 0.0122 - val_loss: 855.2807 - val_accuracy: 0.0115
# Epoch 103/512
# 535/535 [==============================] - 3s 5ms/step - loss: 454.9185 - accuracy: 0.0116 - val_loss: 873.8282 - val_accuracy: 0.0115
# Epoch 104/512
# 535/535 [==============================] - 3s 5ms/step - loss: 441.2491 - accuracy: 0.0119 - val_loss: 912.3306 - val_accuracy: 0.0115
# Epoch 105/512
# 535/535 [==============================] - 3s 5ms/step - loss: 728.8329 - accuracy: 0.0113 - val_loss: 1000.6235 - val_accuracy: 0.0115
# Epoch 106/512
# 535/535 [==============================] - 3s 5ms/step - loss: 467.5800 - accuracy: 0.0112 - val_loss: 1116.3871 - val_accuracy: 0.0115
# Epoch 107/512
# 535/535 [==============================] - 3s 5ms/step - loss: 405.9771 - accuracy: 0.0116 - val_loss: 966.2594 - val_accuracy: 0.0115
# Epoch 108/512
# 535/535 [==============================] - 3s 5ms/step - loss: 432.3007 - accuracy: 0.0120 - val_loss: 862.2850 - val_accuracy: 0.0115
# Epoch 109/512
# 535/535 [==============================] - 3s 5ms/step - loss: 478.2287 - accuracy: 0.0111 - val_loss: 1058.7542 - val_accuracy: 0.0115
# Epoch 110/512
# 535/535 [==============================] - 3s 5ms/step - loss: 729.1957 - accuracy: 0.0120 - val_loss: 860.8839 - val_accuracy: 0.0000e+00
# Epoch 111/512
# 535/535 [==============================] - 3s 5ms/step - loss: 523.4201 - accuracy: 0.0123 - val_loss: 939.7157 - val_accuracy: 0.0115
# Epoch 112/512
# 535/535 [==============================] - 3s 5ms/step - loss: 402.2982 - accuracy: 0.0118 - val_loss: 953.1226 - val_accuracy: 0.0115
# Epoch 113/512
# 535/535 [==============================] - 3s 5ms/step - loss: 441.6714 - accuracy: 0.0115 - val_loss: 796.9461 - val_accuracy: 0.0000e+00
# Epoch 114/512
# 535/535 [==============================] - 3s 5ms/step - loss: 453.6731 - accuracy: 0.0115 - val_loss: 956.7260 - val_accuracy: 0.0115
# Epoch 115/512
# 535/535 [==============================] - 3s 5ms/step - loss: 442.2304 - accuracy: 0.0119 - val_loss: 1115.4896 - val_accuracy: 0.0115
# Epoch 116/512
# 535/535 [==============================] - 3s 5ms/step - loss: 543.0690 - accuracy: 0.0118 - val_loss: 1106.1644 - val_accuracy: 0.0115
# Epoch 117/512
# 535/535 [==============================] - 3s 5ms/step - loss: 409.9602 - accuracy: 0.0119 - val_loss: 911.1069 - val_accuracy: 0.0115
# Epoch 118/512
# 535/535 [==============================] - 3s 5ms/step - loss: 405.1177 - accuracy: 0.0117 - val_loss: 1107.7950 - val_accuracy: 0.0115
# Epoch 119/512
# 535/535 [==============================] - 3s 5ms/step - loss: 398.2818 - accuracy: 0.0116 - val_loss: 974.8116 - val_accuracy: 0.0000e+00
# Epoch 120/512
# 535/535 [==============================] - 3s 5ms/step - loss: 388.0456 - accuracy: 0.0119 - val_loss: 1201.4424 - val_accuracy: 0.0115
# Epoch 121/512
# 535/535 [==============================] - 3s 5ms/step - loss: 348.4368 - accuracy: 0.0119 - val_loss: 1011.3489 - val_accuracy: 0.0115
# Epoch 122/512
# 535/535 [==============================] - 3s 5ms/step - loss: 455.0468 - accuracy: 0.0116 - val_loss: 955.1679 - val_accuracy: 0.0115
# Epoch 123/512
# 535/535 [==============================] - 3s 5ms/step - loss: 775.1484 - accuracy: 0.0113 - val_loss: 999.7378 - val_accuracy: 0.0115
# Epoch 124/512
# 535/535 [==============================] - 3s 5ms/step - loss: 451.2010 - accuracy: 0.0117 - val_loss: 1116.0513 - val_accuracy: 0.0115
# Epoch 125/512
# 535/535 [==============================] - 3s 5ms/step - loss: 339.9175 - accuracy: 0.0117 - val_loss: 998.3182 - val_accuracy: 0.0000e+00
# Epoch 126/512
# 535/535 [==============================] - 3s 5ms/step - loss: 330.8389 - accuracy: 0.0120 - val_loss: 1130.8542 - val_accuracy: 0.0115
# Epoch 127/512
# 535/535 [==============================] - 3s 5ms/step - loss: 316.0284 - accuracy: 0.0116 - val_loss: 863.6379 - val_accuracy: 0.0000e+00
# Epoch 128/512
# 535/535 [==============================] - 3s 5ms/step - loss: 439.8718 - accuracy: 0.0122 - val_loss: 1023.4769 - val_accuracy: 0.0115
# Epoch 129/512
# 535/535 [==============================] - 3s 5ms/step - loss: 390.9926 - accuracy: 0.0117 - val_loss: 847.0335 - val_accuracy: 0.0115
# Epoch 130/512
# 535/535 [==============================] - 3s 5ms/step - loss: 388.8368 - accuracy: 0.0117 - val_loss: 1021.3794 - val_accuracy: 0.0115
# Epoch 131/512
# 535/535 [==============================] - 3s 5ms/step - loss: 368.5113 - accuracy: 0.0113 - val_loss: 1015.4575 - val_accuracy: 0.0115
# Epoch 132/512
# 535/535 [==============================] - 3s 5ms/step - loss: 392.2841 - accuracy: 0.0116 - val_loss: 913.4328 - val_accuracy: 0.0115
# Epoch 133/512
# 535/535 [==============================] - 3s 5ms/step - loss: 325.2948 - accuracy: 0.0116 - val_loss: 927.2391 - val_accuracy: 0.0000e+00
# Epoch 134/512
# 535/535 [==============================] - 3s 5ms/step - loss: 285.1758 - accuracy: 0.0126 - val_loss: 1075.7814 - val_accuracy: 0.0115
# Epoch 135/512
# 535/535 [==============================] - 3s 5ms/step - loss: 354.5406 - accuracy: 0.0116 - val_loss: 1215.4900 - val_accuracy: 0.0115
# Epoch 136/512
# 535/535 [==============================] - 3s 5ms/step - loss: 287.1384 - accuracy: 0.0116 - val_loss: 1095.0388 - val_accuracy: 0.0115
# Epoch 137/512
# 535/535 [==============================] - 3s 5ms/step - loss: 515.0869 - accuracy: 0.0117 - val_loss: 1054.1719 - val_accuracy: 0.0000e+00
# Epoch 138/512
# 535/535 [==============================] - 3s 5ms/step - loss: 349.1100 - accuracy: 0.0122 - val_loss: 988.6633 - val_accuracy: 0.0115
# Epoch 139/512
# 535/535 [==============================] - 3s 5ms/step - loss: 295.2531 - accuracy: 0.0115 - val_loss: 962.8040 - val_accuracy: 0.0115
# Epoch 140/512
# 535/535 [==============================] - 3s 5ms/step - loss: 267.9881 - accuracy: 0.0120 - val_loss: 981.2843 - val_accuracy: 0.0115
# Epoch 141/512
# 535/535 [==============================] - 3s 5ms/step - loss: 306.0102 - accuracy: 0.0118 - val_loss: 953.3603 - val_accuracy: 0.0000e+00
# Epoch 142/512
# 535/535 [==============================] - 3s 5ms/step - loss: 301.1901 - accuracy: 0.0117 - val_loss: 1105.8024 - val_accuracy: 0.0115
# Epoch 143/512
# 535/535 [==============================] - 3s 5ms/step - loss: 365.3666 - accuracy: 0.0119 - val_loss: 1118.7434 - val_accuracy: 0.0115
# Epoch 144/512
# 535/535 [==============================] - 3s 5ms/step - loss: 311.8500 - accuracy: 0.0123 - val_loss: 907.5620 - val_accuracy: 0.0115
# Epoch 145/512
# 535/535 [==============================] - 3s 5ms/step - loss: 292.9550 - accuracy: 0.0115 - val_loss: 1048.4518 - val_accuracy: 0.0000e+00
# Epoch 146/512
# 535/535 [==============================] - 3s 5ms/step - loss: 251.0816 - accuracy: 0.0125 - val_loss: 1151.1625 - val_accuracy: 0.0000e+00
# Epoch 147/512
# 535/535 [==============================] - 3s 5ms/step - loss: 653.6774 - accuracy: 0.0115 - val_loss: 940.3221 - val_accuracy: 0.0000e+00
# Epoch 148/512
# 535/535 [==============================] - 3s 5ms/step - loss: 280.5855 - accuracy: 0.0119 - val_loss: 934.9235 - val_accuracy: 0.0000e+00
# Epoch 149/512
# 535/535 [==============================] - 3s 5ms/step - loss: 225.9128 - accuracy: 0.0119 - val_loss: 953.8062 - val_accuracy: 0.0115
# Epoch 150/512
# 535/535 [==============================] - 3s 5ms/step - loss: 306.5529 - accuracy: 0.0117 - val_loss: 892.3599 - val_accuracy: 0.0115
# Epoch 151/512
# 535/535 [==============================] - 3s 5ms/step - loss: 253.2885 - accuracy: 0.0118 - val_loss: 1110.1475 - val_accuracy: 0.0000e+00
# Epoch 152/512
# 535/535 [==============================] - 3s 5ms/step - loss: 267.0106 - accuracy: 0.0120 - val_loss: 1203.1035 - val_accuracy: 0.0115
# Epoch 153/512
# 535/535 [==============================] - 3s 5ms/step - loss: 311.7899 - accuracy: 0.0119 - val_loss: 1018.3666 - val_accuracy: 0.0115
# Epoch 154/512
# 535/535 [==============================] - 3s 5ms/step - loss: 223.3025 - accuracy: 0.0116 - val_loss: 987.7523 - val_accuracy: 0.0115
# Epoch 155/512
# 535/535 [==============================] - 3s 5ms/step - loss: 353.7555 - accuracy: 0.0117 - val_loss: 2329.7554 - val_accuracy: 0.0115
# Epoch 156/512
# 535/535 [==============================] - 3s 5ms/step - loss: 845.5920 - accuracy: 0.0119 - val_loss: 823.7222 - val_accuracy: 0.0115
# Epoch 157/512
# 535/535 [==============================] - 3s 5ms/step - loss: 291.3281 - accuracy: 0.0122 - val_loss: 906.7766 - val_accuracy: 0.0115
# Epoch 158/512
# 535/535 [==============================] - 3s 5ms/step - loss: 222.8322 - accuracy: 0.0116 - val_loss: 944.5978 - val_accuracy: 0.0000e+00
# Epoch 159/512
# 535/535 [==============================] - 3s 5ms/step - loss: 203.3752 - accuracy: 0.0113 - val_loss: 877.3539 - val_accuracy: 0.0115
# Epoch 160/512
# 535/535 [==============================] - 3s 5ms/step - loss: 243.1462 - accuracy: 0.0112 - val_loss: 1018.5483 - val_accuracy: 0.0000e+00
# Epoch 161/512
# 535/535 [==============================] - 3s 5ms/step - loss: 558.2592 - accuracy: 0.0119 - val_loss: 904.0981 - val_accuracy: 0.0115
# Epoch 162/512
# 535/535 [==============================] - 3s 5ms/step - loss: 224.0364 - accuracy: 0.0120 - val_loss: 976.9720 - val_accuracy: 0.0115
# Epoch 163/512
# 535/535 [==============================] - 3s 5ms/step - loss: 197.7218 - accuracy: 0.0120 - val_loss: 1034.0405 - val_accuracy: 0.0115
# Epoch 164/512
# 535/535 [==============================] - 3s 5ms/step - loss: 218.2399 - accuracy: 0.0112 - val_loss: 1000.0859 - val_accuracy: 0.0115
# Epoch 165/512
# 535/535 [==============================] - 3s 5ms/step - loss: 224.4158 - accuracy: 0.0117 - val_loss: 929.7556 - val_accuracy: 0.0000e+00
# Epoch 166/512
# 535/535 [==============================] - 3s 5ms/step - loss: 487.4278 - accuracy: 0.0100 - val_loss: 1086.4769 - val_accuracy: 0.0115
# Epoch 167/512
# 535/535 [==============================] - 3s 5ms/step - loss: 277.0115 - accuracy: 0.0119 - val_loss: 829.3066 - val_accuracy: 0.0115
# Epoch 168/512
# 535/535 [==============================] - 3s 5ms/step - loss: 226.9101 - accuracy: 0.0118 - val_loss: 1043.7295 - val_accuracy: 0.0115
# Epoch 169/512
# 535/535 [==============================] - 3s 5ms/step - loss: 229.9124 - accuracy: 0.0119 - val_loss: 937.3611 - val_accuracy: 0.0115
# Epoch 170/512
# 535/535 [==============================] - 3s 5ms/step - loss: 224.4736 - accuracy: 0.0118 - val_loss: 918.4995 - val_accuracy: 0.0115
# Epoch 171/512
# 535/535 [==============================] - 3s 5ms/step - loss: 224.0361 - accuracy: 0.0118 - val_loss: 822.2390 - val_accuracy: 0.0000e+00
# Epoch 172/512
# 535/535 [==============================] - 3s 5ms/step - loss: 563.3843 - accuracy: 0.0115 - val_loss: 776.3177 - val_accuracy: 0.0000e+00
# Epoch 173/512
# 535/535 [==============================] - 3s 5ms/step - loss: 360.4896 - accuracy: 0.0111 - val_loss: 1030.3584 - val_accuracy: 0.0115
# Epoch 174/512
# 535/535 [==============================] - 3s 5ms/step - loss: 215.1836 - accuracy: 0.0115 - val_loss: 1062.9989 - val_accuracy: 0.0115
# Epoch 175/512
# 535/535 [==============================] - 3s 5ms/step - loss: 175.6798 - accuracy: 0.0117 - val_loss: 981.5305 - val_accuracy: 0.0115
# Epoch 176/512
# 535/535 [==============================] - 3s 5ms/step - loss: 190.3249 - accuracy: 0.0118 - val_loss: 1072.0717 - val_accuracy: 0.0000e+00
# Epoch 177/512
# 535/535 [==============================] - 3s 5ms/step - loss: 549.6936 - accuracy: 0.0112 - val_loss: 1030.7419 - val_accuracy: 0.0115
# Epoch 178/512
# 535/535 [==============================] - 3s 5ms/step - loss: 292.9618 - accuracy: 0.0113 - val_loss: 1078.6536 - val_accuracy: 0.0115
# Epoch 179/512
# 535/535 [==============================] - 3s 5ms/step - loss: 218.2836 - accuracy: 0.0117 - val_loss: 1148.2244 - val_accuracy: 0.0115
# Epoch 180/512
# 535/535 [==============================] - 3s 5ms/step - loss: 193.7475 - accuracy: 0.0120 - val_loss: 1017.3296 - val_accuracy: 0.0115
# Epoch 181/512
# 535/535 [==============================] - 3s 6ms/step - loss: 166.2147 - accuracy: 0.0124 - val_loss: 987.5181 - val_accuracy: 0.0115
# Epoch 182/512
# 535/535 [==============================] - 3s 5ms/step - loss: 205.4111 - accuracy: 0.0115 - val_loss: 987.3824 - val_accuracy: 0.0115
# Epoch 183/512
# 535/535 [==============================] - 3s 5ms/step - loss: 194.9151 - accuracy: 0.0112 - val_loss: 950.7172 - val_accuracy: 0.0000e+00
# Epoch 184/512
# 535/535 [==============================] - 3s 5ms/step - loss: 209.9887 - accuracy: 0.0117 - val_loss: 1031.0056 - val_accuracy: 0.0000e+00
# Epoch 185/512
# 535/535 [==============================] - 3s 5ms/step - loss: 216.3389 - accuracy: 0.0116 - val_loss: 1252.1218 - val_accuracy: 0.0000e+00
# Epoch 186/512
# 535/535 [==============================] - 3s 5ms/step - loss: 278.6714 - accuracy: 0.0110 - val_loss: 1013.6780 - val_accuracy: 0.0115
# Epoch 187/512
# 535/535 [==============================] - 3s 5ms/step - loss: 491.5817 - accuracy: 0.0111 - val_loss: 958.6663 - val_accuracy: 0.0115
# Epoch 188/512
# 535/535 [==============================] - 3s 5ms/step - loss: 278.4343 - accuracy: 0.0117 - val_loss: 953.4556 - val_accuracy: 0.0115
# Epoch 189/512
# 535/535 [==============================] - 3s 5ms/step - loss: 156.4161 - accuracy: 0.0118 - val_loss: 1006.2902 - val_accuracy: 0.0115
# Epoch 190/512
# 535/535 [==============================] - 3s 5ms/step - loss: 165.9531 - accuracy: 0.0120 - val_loss: 1041.5742 - val_accuracy: 0.0000e+00
# Epoch 191/512
# 535/535 [==============================] - 3s 5ms/step - loss: 169.6544 - accuracy: 0.0112 - val_loss: 916.8371 - val_accuracy: 0.0115
# Epoch 192/512
# 535/535 [==============================] - 3s 5ms/step - loss: 166.8579 - accuracy: 0.0117 - val_loss: 1167.7115 - val_accuracy: 0.0115
# Epoch 193/512
# 535/535 [==============================] - 3s 5ms/step - loss: 232.5008 - accuracy: 0.0119 - val_loss: 960.1794 - val_accuracy: 0.0115
# Epoch 194/512
# 535/535 [==============================] - 3s 5ms/step - loss: 266.8208 - accuracy: 0.0116 - val_loss: 996.6648 - val_accuracy: 0.0000e+00
# Epoch 195/512
# 535/535 [==============================] - 3s 5ms/step - loss: 266.9730 - accuracy: 0.0119 - val_loss: 906.5483 - val_accuracy: 0.0115
# Epoch 196/512
# 535/535 [==============================] - 3s 5ms/step - loss: 169.5936 - accuracy: 0.0117 - val_loss: 952.5777 - val_accuracy: 0.0115
# Epoch 197/512
# 535/535 [==============================] - 3s 5ms/step - loss: 143.1175 - accuracy: 0.0122 - val_loss: 885.6818 - val_accuracy: 0.0115
# Epoch 198/512
# 535/535 [==============================] - 3s 5ms/step - loss: 166.6655 - accuracy: 0.0118 - val_loss: 920.3492 - val_accuracy: 0.0115

# %%
predicted = model.predict(y,batch_size=32)
model.evaluate(y,x,batch_size=32)
# Out:
# 187/271 [===================>..........] - ETA: 0s
# 271/271 [==============================] - 1s 2ms/step
# 271/271 [==============================] - 1s 3ms/step - loss: 148.5725 - accuracy: 0.0125
# [148.57249450683594, 0.012492770329117775]

# %%
def check(i):
    import math
    if i< 0:
        return 0
    else:
        return math.floor(i)

# %%
checked = np.array([check(i) for i in predicted]).reshape(predicted.shape[0],1)
r2 = 1 -  np.sum((checked - x)**2) / np.sum((x - np.mean(x))**2)
print(r2)
# Out:
# 0.9916811490917611

# %%
plt.figure(figsize=(100,10))
plt.plot(range(0,len(checked)),checked, color="r", label="predict_data")
plt.plot(range(0, len(x)), x, color="b", label="row_data", alpha=0.5)
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(range(0,len(checked)),checked, color="r", label="predict_data")
plt.plot(range(0, len(x)), x, color="b", label="row_data", alpha=0.5)
plt.legend()
plt.show()

# %%
predictedz = model.predict(z,batch_size=32)
checkedz = np.array([check(i) for i in predictedz]).reshape(predictedz.shape[0],1)

plt.figure(figsize=(10,5))
plt.plot(range(0,len(checkedz)),checkedz, color="r", label="predict_data")
plt.legend()
plt.show()
# Out:
# 273/273 [==============================] - 1s 2ms/step

# %%
osaka_predicted = model.predict(osaka_y)
osaka_checked = np.array([check(i) for i in osaka_predicted]).reshape(osaka_predicted.shape[0],1)
plt.figure(figsize=(100,10))
plt.plot(range(0,len(osaka_checked)),osaka_checked, color="r", label="predict_data")
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(range(0,len(osaka_checked)),osaka_checked, color="r", label="predict_data")
plt.legend()
plt.show()
# Out:
# 274/274 [==============================] - 0s 2ms/step

# %%
osaka_data3 = np.hstack((osaka_data,osaka_checked))
np.savetxt(".tsvってなに？.csv",osaka_data3,delimiter=",",fmt="%s")
